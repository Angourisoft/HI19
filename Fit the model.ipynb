# %% [markdown]
# # HIModel fit

# %%
import sys
import os
sys.path.append(os.path.abspath("HI19"))

# %%
from hypo2.base.cache import Cache

# %%
from hypo2.model import HIModel

# %%
from hypo2.config import RunConfig

class MyConfig(RunConfig):
    #MODEL_PATH = "D:/main/ml_prj/SchoolHWA/him_avg"
    #BACKUP_DIRECTORY = "D:/main/ml_prj/SchoolHWA/backups/"
    #MODEL_PATH = "D:/main/ml_prj/SchoolHWA/him_basic"
    MODEL_PATH = "D:/main/ml_prj/HWA/model_complicated"
    #MODEL_PATH = "D:/main/ml_prj/SchoolHWA/class_models/h1562593347_0.7733333333333333_13_classes.h5"
    BACKUP_DIRECTORY = "D:/main/ml_prj/HWA/model_backups/"
    N_EPOCHS = 3600
    BATCH_SIZE = 3
    #RESNET_LAYERS = [2, 3, 3, 2]
    #RESNET_LAYERS = [3, 4, 23, 3]
    #RESNET_LAYERS = [3, 4, 6, 3]
    RESNET_LAYERS = [6, 10, 14, 6]
    CACHE_PATH = "D:/main/ml_prj/HWA/tmp/cache/"

config = MyConfig()

# %%
DATA_PATH = r"C:\ml_prj\SchoolHWA\data2"

# %%
from hypo2.addit.functions import Functional as F
paths = F.gen_paths(DATA_PATH)[:60]

# %%
import random
from hypo2.api import FitEnv

def fitit(class_count):
    cfg = MyConfig()
    cfg.CLASS_COUNT = class_count
    cfg.N_EPOCHS = class_count * 300
    id = random.randint(0, len(paths) - cfg.CLASS_COUNT - 1)
    pp = paths[id : id + cfg.CLASS_COUNT]
    fit = FitEnv(cfg)
    fit.fit(pp, verbose=True, plot=True)
    fit.save()
    Cache(cfg).clear()

# %%
fitit(4)
# Out:
# acc: 0.531
# loss: 1.174
# last val acc: 0.617
# 2.6 epochs per second
# 384.17 seconds for 1000 epochs
# Last backup is saved to D:/main/ml_prj/HWA/model_backups/HI1575392685/model_999

# %%
fitit(4)
# Out:
# acc: 0.91
# loss: 0.84
# last val acc: 0.865
# 2.55 epochs per second
# 392.09 seconds for 1000 epochs
# Last backup is saved to D:/main/ml_prj/SchoolHWA/model_backups/HI1575003722/model_999

# %%
fitit(4)
# Out:
# acc: 0.844
# loss: 0.949
# last val acc: 0.94
# 2.61 epochs per second
# 383.52 seconds for 1000 epochs
# Last backup is saved to D:/main/ml_prj/SchoolHWA/model_backups/HI1575004245/model_999

# %%
fitit(4)
# Out:
# acc: 0.93
# loss: 0.881
# last val acc: 0.948
# 2.6 epochs per second
# 384.94 seconds for 1000 epochs
# Last backup is saved to D:/main/ml_prj/SchoolHWA/model_backups/HI1575004753/model_999

# %%
fitit(4)
# Out:
# acc: 0.839
# loss: 0.927
# last val acc: 0.921
# 2.8 epochs per second
# 357.44 seconds for 1000 epochs
# Last backup is saved to D:/main/ml_prj/SchoolHWA/model_backups/HI1575005256/model_999

# %%
fitit(4)
# Out:
# acc: 0.939
# loss: 0.842
# last val acc: 0.906
# 2.54 epochs per second
# 394.03 seconds for 1000 epochs
# Last backup is saved to D:/main/ml_prj/SchoolHWA/model_backups/HI1575005733/model_999

# %%
fitit(6)
# Out:
# acc: 0.854
# loss: 1.31
# last val acc: 0.933
# 2.67 epochs per second
# 375.0 seconds for 1000 epochs
# Last backup is saved to D:/main/ml_prj/SchoolHWA/model_backups/HI1575006239/model_1499

# %%
fitit(12)
# Out:
# acc: 0.626
# loss: 2.02
# last val acc: 0.617
# 2.7 epochs per second
# 370.67 seconds for 1000 epochs
# Last backup is saved to D:/main/ml_prj/SchoolHWA/model_backups/HI1575007072/model_3499

# %%
fitit(16)
# Out:
# acc: 0.536
# loss: 2.372
# last val acc: 0.454
# 2.8 epochs per second
# 357.24 seconds for 1000 epochs
# Last backup is saved to D:/main/ml_prj/SchoolHWA/model_backups/HI1575008638/model_4499

# %%
fitit(24)
# Out:
# acc: 0.447
# loss: 2.864
# last val acc: 0.425
# 2.75 epochs per second
# 363.18 seconds for 1000 epochs
# Last backup is saved to D:/main/ml_prj/SchoolHWA/model_backups/HI1575010758/model_6999

# %%
fitit(24)
# Out:
# acc: 0.438
# loss: 2.858
# last val acc: 0.429
# 2.77 epochs per second
# 360.49 seconds for 1000 epochs
# Last backup is saved to D:/main/ml_prj/SchoolHWA/model_backups/HI1575013666/model_6999

# %%
fitit(24)
# Out:
# acc: 0.306
# loss: 2.953
# last val acc: 0.425
# 2.6 epochs per second
# 384.07 seconds for 1000 epochs
# Last backup is saved to D:/main/ml_prj/SchoolHWA/model_backups/HI1575016623/model_6999

# %%
cfg = MyConfig()
vpaths = F.gen_paths(DATA_PATH)[61:]
actpaths = vpaths[:]

# %%
from hypo2.addit.visualizer import Visualizer
from hypo2.dataset import Dataset
cfg.CLASS_COUNT = len(actpaths)
v = Visualizer(cfg)

# %%
from hypo2.addit.functions import Functional as F

# %%
ds = Dataset(cfg)
X, y = ds.gen_dataset(actpaths, True)
fXl, fyl = v.get_centers_from_xy(X, y)
# Out:
# 100 %
# ...

# %%
from sklearn.decomposition import PCA
from sklearn.manifold import TSNE
import matplotlib.pyplot as plt
plt.figure(figsize=[20, 20])
#v.build_comp(fXl, fyl, PCA)
v.build_comp(fXl, fyl, TSNE)

# %%
image = runenv.open_image("C:/ml_prj/SchoolHWA/data2/001-Bikmullina-Z.R-1-tur/4.png")
center, weight = runenv.get_center(image)
print("OK" if weight != 0 else "WA")
# Out:
# OK

# %%
from hypo2.api import RunEnv
runenv = RunEnv(config)

# %%
from hypo2.projecttest.projecttest import validate

# %%
validate(cfg, HIModel(cfg), actpaths, 100)
# Out:
# ...
# C:\ml_prj\SchoolHWA\data2/062-Pogarskaya-A.V-1-tur missed, not enough words: 27
# C:\ml_prj\SchoolHWA\data2/062-Pogarskaya-A.V-2-tur missed, not enough words: 64
# C:\ml_prj\SchoolHWA\data2/063-Anoshkin-D.G missed, not enough words: 122
# C:\ml_prj\SchoolHWA\data2/074-SHumin-I.A missed, not enough words: 151
# C:\ml_prj\SchoolHWA\data2/082-Syamina-A.A missed, not enough words: 131
# C:\ml_prj\SchoolHWA\data2/088-Petrova-D.S missed, not enough words: 105

# %%
from hypo2.projecttest.projecttest import validate, test_project
from hypo2.model import HIModel
import time
t = time.time()
print(test_project(cfg, HIModel(cfg), actpaths))
print((time.time() - t) / 60, "min")
# Out:
# ...
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-27-f4f968053db0> in <module>
#       3 import time
#       4 t = time.time()
# ----> 5 print(test_project(cfg, HIModel(cfg), actpaths))
#       6 print((time.time() - t) / 60, "min")
#
# C:\ml_prj\SchoolHWA\hypo2\projecttest\projecttest.py in test_project(config, model, paths)
#      86
#      87     for pax in tqdm([1, 2, 10, 25, 70, 200]):
# ---> 88         thrs.append(validate(config, model, paths, pax, False))
#      89
#      90     print("Thresholds:", thrs)
#
# C:\ml_prj\SchoolHWA\hypo2\projecttest\projecttest.py in validate(config, model, paths, PAX, verbose)
#      67         thr = (allnums[i] + allnums[i + 1]) / 2
#      68         XXX.append(thr)
# ---> 69         acc = countacc(X_dists, y_dists, thr)
#      70         ns.append(acc)
#      71         if acc > bacc:
#
# ...

# %% [markdown]
# NORMALLY FITTED
#
# 2  0.63 18
#
# 40 0.74 11
#
# 150 0.86 11
#
#
# WELL FITTED
#
# 150 0.83 19
#
# 2 0.62 28

# %% [markdown]
# 80% - for BASIC
